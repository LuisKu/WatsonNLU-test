# %% [markdown]
# # Python and Analytics workshop - Using Natural Language Understanding and Sentiment

# %% [markdown]
# In this portion of the workshop, we'll use an instance of [Watson Natural Language Understanding](https://cloud.ibm.com/catalog/services/natural-language-understanding) to gather insights into data.
#
# Watson Natural Language Understanding is a cloud native product that uses deep learning to extract metadata from text such as entities, keywords, categories, sentiment, emotion, relations, and syntax.
# There is a rich [API](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python) that we will use along with the [Watson Python SDK](https://github.com/watson-developer-cloud/python-sdk) to analyze our data.

# %% [markdown]
# ## Contents
#
# - [1.0 Setup - install modules](#setup)
# - [2.0 Test NLU APIs](#test)
# - [3.0 Import Data and Setup Pandas Dataframe ](#pandas)
# - [4.0 Clean and Prepare data for NLU scoring](#clean)
# - [5.0 Analyze response from NLU ](#analyze)
# - [6.0 Get sentiment by row](#sentiment-row)
# - [7.0 Graph with matplotlib](#graph)

# %% [markdown]
# ## 1.0 Setup - Install Modules<a name="setup"></a>

# %% [markdown]
# We use the [Watson Python SDK](https://github.com/watson-developer-cloud/python-sdk) to access the [NLU APIs](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python) programatically.

# %%
# !pip install --upgrade numpy==1.18.5
# !pip install --upgrade pandas==1.0.5
# !pip install --upgrade ibm-watson==4.7.1
# !pip install PyJWT==1.7.1
# Out:
# Requirement already satisfied: numpy==1.18.5 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (1.18.5)
# Requirement already satisfied: pandas==1.0.5 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from pandas==1.0.5) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from pandas==1.0.5) (2021.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from pandas==1.0.5) (1.18.5)
# Requirement already satisfied: six>=1.5 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from python-dateutil>=2.6.1->pandas==1.0.5) (1.15.0)
# Requirement already satisfied: ibm-watson==4.7.1 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (4.7.1)
# Requirement already satisfied: ibm-cloud-sdk-core==1.7.3 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from ibm-watson==4.7.1) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from ibm-watson==4.7.1) (2.8.1)
# Requirement already satisfied: websocket-client==0.48.0 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from ibm-watson==4.7.1) (0.48.0)
# Requirement already satisfied: requests<3.0,>=2.0 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from ibm-watson==4.7.1) (2.26.0)
# Requirement already satisfied: PyJWT>=1.7.1 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from ibm-cloud-sdk-core==1.7.3->ibm-watson==4.7.1) (2.1.0)
# Requirement already satisfied: six in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from websocket-client==0.48.0->ibm-watson==4.7.1) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from requests<3.0,>=2.0->ibm-watson==4.7.1) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from requests<3.0,>=2.0->ibm-watson==4.7.1) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from requests<3.0,>=2.0->ibm-watson==4.7.1) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luisk\desktop\sample_project_1\env\lib\site-packages (from requests<3.0,>=2.0->ibm-watson==4.7.1) (3.2)
# Collecting PyJWT==1.7.1
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Installing collected packages: PyJWT
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.1.0
#     Uninstalling PyJWT-2.1.0:
#       Successfully uninstalled PyJWT-2.1.0
# Successfully installed PyJWT-1.7.1

# %% [markdown]
# ### Important: Restart the Jupyter kernel now
# Restart the kernal by going to the `Kernel` tab above and choosing `Restart`.

# %% [markdown]
# Import python modules from the Watson Python SDKs

# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features,KeywordsOptions,SentimentOptions

# %% [markdown]
# ### 1.1 Add NLU credentials
# Get the [IAM Authentication Key](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python#authentication) and [Service URL](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python#service-endpoint) that you obtained when you [Created a Watson NLU instance](https://github.ibm.com/IBMDeveloper/python-and-analytics/tree/addNLU/workshop/natural-language-understanding#create-a-watson-nlu-instance).

# %% [markdown]
# Add your [IAM Authentication Key](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python#authentication) below.

# %%
IAM_KEY = '***************************'

# %% [markdown]
# Add your [NLU Service URL](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python#service-endpoint) below

# %%
SERVICE_URL = '*************************************a775c91'

# %% [markdown]
# ## 2.0 NLU APIs <a name="test"></a>
# Run a quick check to make sure everything is working. We'll use a [basic web page](https://www.ibm.com) to see how Watson Natural Language Understanding can extract categories when given a URL. [This example](https://cloud.ibm.com/apidocs/natural-language-understanding?code=python#categories) comes from the Watson NLU documentation.

# %%
authenticator = IAMAuthenticator(IAM_KEY)
natural_language_understanding = NaturalLanguageUnderstandingV1(version='2020-08-01',authenticator=authenticator)

natural_language_understanding.set_service_url(SERVICE_URL)
response = natural_language_understanding.analyze(
    text='Compartimos la actualización de datos sobre #COVID19 en nuestro país.Domingo 25 de julio de 2021.#ProtégetePanamá#UnidosVenceremos',
    features=Features(keywords=KeywordsOptions(limit=3))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 130,
#     "features": 1
#   },
#   "language": "es",
#   "keywords": [
#     {
#       "text": "actualizaci\u00f3n de datos",
#       "relevance": 0.992122,
#       "count": 1
#     },
#     {
#       "text": "#COVID19",
#       "relevance": 0.35094,
#       "count": 1
#     },
#     {
#       "text": "pa\u00eds",
#       "relevance": 0.336484,
#       "count": 1
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
    text='Compartimos la actualización de datos sobre #COVID19 en nuestro país.Domingo 25 de julio de 2021.#ProtégetePanamá#UnidosVenceremos',
    features=Features(sentiment=SentimentOptions())).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 130,
#     "features": 1
#   },
#   "sentiment": {
#     "document": {
#       "score": 0,
#       "label": "neutral"
#     }
#   },
#   "language": "es"
# }

# %% [markdown]
# ## 3.0 Import Data and Setup Pandas Dataframe <a name="pandas"></a>

# %%
import os, types
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/LuisKu/WatsonNLU-test/main/insta_data2.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/LuisKu/WatsonNLU-test/main/insta_data3.csv')

# %%
df.head(5)
# Out:
#    numero de post                                       commentarios
# 0               1       Circuito 8-10 para cuándo estará programado?
# 1               1                                                👏👏👏
# 2               2  De verdad aún no entiendo… nuevas medidas y si...
# 3               2  Siempre dice; arraijan, vista alegre_ arraijan...
# 4               2  Quisiera saber donde están vacunando la 2a dos...

# %% [markdown]
# ## 4.0 Get sentiment by row <a name="sentiment-row"></a>
# Now, let's derive some sentiment and emotion information on a per-row basis, to provide more granualarity.
# The number of API calls that you can make to Watson NLU is [rate limited and dependent on your service plan](https://cloud.ibm.com/catalog/services/natural-language-understanding), so in order to limit the number of API calls to the NLU endpoint we'll start with just 50 rows by setting `num_rows` to 50.

# %%
df_rows = df

# %%
sentimentComentario = []

for index, row in df_rows.iterrows():
    
    response = natural_language_understanding.analyze(
    text = row['commentarios'],
    features=Features(sentiment=SentimentOptions()),
    language='es').get_result()
    sentimentComentario.append(response)

# %%
sentimentComentario
# Out:
# [{'usage': {'text_units': 1, 'text_characters': 44, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.524743, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 203, 'features': 1},
#   'sentiment': {'document': {'score': -0.578034, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 114, 'features': 1},
#   'sentiment': {'document': {'score': 0.892413, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 75, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 56, 'features': 1},
#   'sentiment': {'document': {'score': -0.647574, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 41, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 69, 'features': 1},
#   'sentiment': {'document': {'score': -0.741931, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 84, 'features': 1},
#   'sentiment': {'document': {'score': -0.560431, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 158, 'features': 1},
#   'sentiment': {'document': {'score': -0.614271, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 646, 'features': 1},
#   'sentiment': {'document': {'score': -0.679075, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 58, 'features': 1},
#   'sentiment': {'document': {'score': -0.751621, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 38, 'features': 1},
#   'sentiment': {'document': {'score': -0.93621, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 80, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 23, 'features': 1},
#   'sentiment': {'document': {'score': -0.785641, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 61, 'features': 1},
#   'sentiment': {'document': {'score': -0.833686, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 27, 'features': 1},
#   'sentiment': {'document': {'score': -0.938435, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 69, 'features': 1},
#   'sentiment': {'document': {'score': -0.409085, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 19, 'features': 1},
#   'sentiment': {'document': {'score': -0.926303, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 19, 'features': 1},
#   'sentiment': {'document': {'score': -0.653468, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 83, 'features': 1},
#   'sentiment': {'document': {'score': -0.684761, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 320, 'features': 1},
#   'sentiment': {'document': {'score': -0.662516, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 33, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0.718481, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 81, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 92, 'features': 1},
#   'sentiment': {'document': {'score': -0.77057, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 231, 'features': 1},
#   'sentiment': {'document': {'score': -0.615752, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 18, 'features': 1},
#   'sentiment': {'document': {'score': 0.339291, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 45, 'features': 1},
#   'sentiment': {'document': {'score': -0.835592, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 36, 'features': 1},
#   'sentiment': {'document': {'score': -0.306484, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 33, 'features': 1},
#   'sentiment': {'document': {'score': -0.728351, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 146, 'features': 1},
#   'sentiment': {'document': {'score': -0.618323, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 68, 'features': 1},
#   'sentiment': {'document': {'score': -0.779994, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 108, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 91, 'features': 1},
#   'sentiment': {'document': {'score': -0.95449, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 160, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 57, 'features': 1},
#   'sentiment': {'document': {'score': -0.515303, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 29, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 28, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 79, 'features': 1},
#   'sentiment': {'document': {'score': -0.570691, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 17, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 45, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 14, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 50, 'features': 1},
#   'sentiment': {'document': {'score': 0.761891, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 25, 'features': 1},
#   'sentiment': {'document': {'score': -0.497917, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 115, 'features': 1},
#   'sentiment': {'document': {'score': -0.387005, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 8, 'features': 1},
#   'sentiment': {'document': {'score': 0.411887, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 227, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 15, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 99, 'features': 1},
#   'sentiment': {'document': {'score': -0.700409, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0.981119, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 79, 'features': 1},
#   'sentiment': {'document': {'score': -0.730914, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 27, 'features': 1},
#   'sentiment': {'document': {'score': -0.491421, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 27, 'features': 1},
#   'sentiment': {'document': {'score': -0.491421, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 103, 'features': 1},
#   'sentiment': {'document': {'score': -0.98271, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 114, 'features': 1},
#   'sentiment': {'document': {'score': -0.510083, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 41, 'features': 1},
#   'sentiment': {'document': {'score': -0.685664, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 275, 'features': 1},
#   'sentiment': {'document': {'score': 0.670228, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 109, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 61, 'features': 1},
#   'sentiment': {'document': {'score': -0.68869, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0.59399, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 630, 'features': 1},
#   'sentiment': {'document': {'score': -0.810313, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 45, 'features': 1},
#   'sentiment': {'document': {'score': 0.985625, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 272, 'features': 1},
#   'sentiment': {'document': {'score': -0.870335, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.524743, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 6, 'features': 1},
#   'sentiment': {'document': {'score': 0.636614, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0.59399, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 8, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 9, 'features': 1},
#   'sentiment': {'document': {'score': 0.998324, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 87, 'features': 1},
#   'sentiment': {'document': {'score': 0.98684, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 87, 'features': 1},
#   'sentiment': {'document': {'score': 0.98684, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 15, 'features': 1},
#   'sentiment': {'document': {'score': 0.863251, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 170, 'features': 1},
#   'sentiment': {'document': {'score': -0.594929, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 7, 'features': 1},
#   'sentiment': {'document': {'score': -0.624769, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 63, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 146, 'features': 1},
#   'sentiment': {'document': {'score': -0.747231, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 364, 'features': 1},
#   'sentiment': {'document': {'score': -0.718412, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 78, 'features': 1},
#   'sentiment': {'document': {'score': -0.735339, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 80, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 34, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 199, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 61, 'features': 1},
#   'sentiment': {'document': {'score': -0.599345, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 127, 'features': 1},
#   'sentiment': {'document': {'score': -0.424602, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 62, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 89, 'features': 1},
#   'sentiment': {'document': {'score': -0.327425, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 51, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 47, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0.981119, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 28, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 58, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 33, 'features': 1},
#   'sentiment': {'document': {'score': -0.727639, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 14, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 32, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 114, 'features': 1},
#   'sentiment': {'document': {'score': -0.482081, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 124, 'features': 1},
#   'sentiment': {'document': {'score': -0.87738, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 106, 'features': 1},
#   'sentiment': {'document': {'score': -0.716774, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 51, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 41, 'features': 1},
#   'sentiment': {'document': {'score': 0.996623, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 150, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 19, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 30, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 29, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.524743, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0.899964, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 11, 'features': 1},
#   'sentiment': {'document': {'score': 0.895945, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 27, 'features': 1},
#   'sentiment': {'document': {'score': -0.658462, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.990966, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 55, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 235, 'features': 1},
#   'sentiment': {'document': {'score': -0.630266, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 68, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 122, 'features': 1},
#   'sentiment': {'document': {'score': -0.926352, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 268, 'features': 1},
#   'sentiment': {'document': {'score': -0.837631, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 219, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 111, 'features': 1},
#   'sentiment': {'document': {'score': 0.277607, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 23, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 69, 'features': 1},
#   'sentiment': {'document': {'score': 0.72845, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 43, 'features': 1},
#   'sentiment': {'document': {'score': -0.889369, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 89, 'features': 1},
#   'sentiment': {'document': {'score': -0.955703, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 117, 'features': 1},
#   'sentiment': {'document': {'score': 0.293204, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 43, 'features': 1},
#   'sentiment': {'document': {'score': 0.268975, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0.900665, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 340, 'features': 1},
#   'sentiment': {'document': {'score': -0.241873, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 114, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 78, 'features': 1},
#   'sentiment': {'document': {'score': 0.901545, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 111, 'features': 1},
#   'sentiment': {'document': {'score': 0.277607, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 84, 'features': 1},
#   'sentiment': {'document': {'score': -0.998583, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 35, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 146, 'features': 1},
#   'sentiment': {'document': {'score': -0.827403, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 162, 'features': 1},
#   'sentiment': {'document': {'score': -0.608813, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 156, 'features': 1},
#   'sentiment': {'document': {'score': -0.5143, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 505, 'features': 1},
#   'sentiment': {'document': {'score': -0.65463, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 42, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 517, 'features': 1},
#   'sentiment': {'document': {'score': -0.709855, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 20, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 107, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 126, 'features': 1},
#   'sentiment': {'document': {'score': -0.761907, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 39, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 141, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 112, 'features': 1},
#   'sentiment': {'document': {'score': -0.370662, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 9, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 35, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 34, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 39, 'features': 1},
#   'sentiment': {'document': {'score': 0.456786, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 26, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0.940573, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 22, 'features': 1},
#   'sentiment': {'document': {'score': 0.278369, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 63, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 60, 'features': 1},
#   'sentiment': {'document': {'score': -0.636667, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 60, 'features': 1},
#   'sentiment': {'document': {'score': -0.636667, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 32, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': -0.763152, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 27, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 42, 'features': 1},
#   'sentiment': {'document': {'score': -0.529566, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 32, 'features': 1},
#   'sentiment': {'document': {'score': 0.746038, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 87, 'features': 1},
#   'sentiment': {'document': {'score': -0.716172, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 40, 'features': 1},
#   'sentiment': {'document': {'score': 0.866624, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 29, 'features': 1},
#   'sentiment': {'document': {'score': -0.842346, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 17, 'features': 1},
#   'sentiment': {'document': {'score': 0.994083, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 48, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 91, 'features': 1},
#   'sentiment': {'document': {'score': -0.843311, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 116, 'features': 1},
#   'sentiment': {'document': {'score': 0.983998, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 298, 'features': 1},
#   'sentiment': {'document': {'score': -0.687378, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1046, 'features': 1},
#   'sentiment': {'document': {'score': -0.689316, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0.900665, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 294, 'features': 1},
#   'sentiment': {'document': {'score': -0.567485, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 207, 'features': 1},
#   'sentiment': {'document': {'score': -0.933949, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 39, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 15, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 288, 'features': 1},
#   'sentiment': {'document': {'score': -0.916235, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.524743, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0.977306, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 38, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 30, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0.59399, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 46, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 32, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 44, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 97, 'features': 1},
#   'sentiment': {'document': {'score': -0.765748, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 199, 'features': 1},
#   'sentiment': {'document': {'score': -0.481233, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 349, 'features': 1},
#   'sentiment': {'document': {'score': -0.803639, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 92, 'features': 1},
#   'sentiment': {'document': {'score': -0.581723, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 111, 'features': 1},
#   'sentiment': {'document': {'score': -0.714874, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 38, 'features': 1},
#   'sentiment': {'document': {'score': 0.58804, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 11, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 63, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 60, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 51, 'features': 1},
#   'sentiment': {'document': {'score': -0.708072, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 50, 'features': 1},
#   'sentiment': {'document': {'score': -0.350967, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 107, 'features': 1},
#   'sentiment': {'document': {'score': -0.430743, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': -0.988575, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 31, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 19, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 86, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 155, 'features': 1},
#   'sentiment': {'document': {'score': 0.511143, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 16, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 80, 'features': 1},
#   'sentiment': {'document': {'score': -0.932919, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 223, 'features': 1},
#   'sentiment': {'document': {'score': -0.502994, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 74, 'features': 1},
#   'sentiment': {'document': {'score': 0.993933, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 378, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 44, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 61, 'features': 1},
#   'sentiment': {'document': {'score': 0.479406, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 415, 'features': 1},
#   'sentiment': {'document': {'score': -0.37716, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 340, 'features': 1},
#   'sentiment': {'document': {'score': -0.590239, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 71, 'features': 1},
#   'sentiment': {'document': {'score': -0.792978, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 209, 'features': 1},
#   'sentiment': {'document': {'score': 0.324995, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 75, 'features': 1},
#   'sentiment': {'document': {'score': -0.517238, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 79, 'features': 1},
#   'sentiment': {'document': {'score': -0.53434, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 64, 'features': 1},
#   'sentiment': {'document': {'score': -0.762017, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 44, 'features': 1},
#   'sentiment': {'document': {'score': -0.283743, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 52, 'features': 1},
#   'sentiment': {'document': {'score': -0.616953, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 117, 'features': 1},
#   'sentiment': {'document': {'score': -0.864107, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 17, 'features': 1},
#   'sentiment': {'document': {'score': -0.949387, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 42, 'features': 1},
#   'sentiment': {'document': {'score': 0.634245, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 48, 'features': 1},
#   'sentiment': {'document': {'score': -0.682636, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 82, 'features': 1},
#   'sentiment': {'document': {'score': -0.643985, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 80, 'features': 1},
#   'sentiment': {'document': {'score': 0.625762, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 31, 'features': 1},
#   'sentiment': {'document': {'score': -0.68796, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 161, 'features': 1},
#   'sentiment': {'document': {'score': 0.581636, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 78, 'features': 1},
#   'sentiment': {'document': {'score': -0.947532, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 48, 'features': 1},
#   'sentiment': {'document': {'score': -0.575812, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 86, 'features': 1},
#   'sentiment': {'document': {'score': -0.647539, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 482, 'features': 1},
#   'sentiment': {'document': {'score': 0.314872, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 57, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 51, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 70, 'features': 1},
#   'sentiment': {'document': {'score': -0.630229, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 27, 'features': 1},
#   'sentiment': {'document': {'score': -0.461717, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 93, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 52, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 120, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 47, 'features': 1},
#   'sentiment': {'document': {'score': 0.392375, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 23, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 131, 'features': 1},
#   'sentiment': {'document': {'score': -0.238843, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 91, 'features': 1},
#   'sentiment': {'document': {'score': -0.930004, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 9, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 16, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 8, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 26, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 17, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 31, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 48, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 76, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 35, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 11, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 6, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 155, 'features': 1},
#   'sentiment': {'document': {'score': -0.779754, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 98, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 81, 'features': 1},
#   'sentiment': {'document': {'score': 0.924486, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 56, 'features': 1},
#   'sentiment': {'document': {'score': -0.68203, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 7, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 106, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 59, 'features': 1},
#   'sentiment': {'document': {'score': 0.277478, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 9, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 159, 'features': 1},
#   'sentiment': {'document': {'score': 0.341271, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 85, 'features': 1},
#   'sentiment': {'document': {'score': -0.480206, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0.978305, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 69, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 62, 'features': 1},
#   'sentiment': {'document': {'score': 0.937467, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 111, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 94, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 29, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 156, 'features': 1},
#   'sentiment': {'document': {'score': -0.977023, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 29, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 50, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 158, 'features': 1},
#   'sentiment': {'document': {'score': 0.998873, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.524743, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0.957087, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': 0.59399, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 12, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.524743, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0.981119, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 224, 'features': 1},
#   'sentiment': {'document': {'score': -0.793032, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 105, 'features': 1},
#   'sentiment': {'document': {'score': -0.903389, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 66, 'features': 1},
#   'sentiment': {'document': {'score': -0.63162, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 69, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 30, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 176, 'features': 1},
#   'sentiment': {'document': {'score': 0.818243, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 107, 'features': 1},
#   'sentiment': {'document': {'score': -0.519529, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 40, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 35, 'features': 1},
#   'sentiment': {'document': {'score': -0.54285, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 231, 'features': 1},
#   'sentiment': {'document': {'score': -0.865135, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 55, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 142, 'features': 1},
#   'sentiment': {'document': {'score': -0.567706, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 40, 'features': 1},
#   'sentiment': {'document': {'score': 0.97974, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 16, 'features': 1},
#   'sentiment': {'document': {'score': -0.822378, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 137, 'features': 1},
#   'sentiment': {'document': {'score': 0.999956, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 31, 'features': 1},
#   'sentiment': {'document': {'score': 0.988623, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 56, 'features': 1},
#   'sentiment': {'document': {'score': 0.939975, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 25, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 117, 'features': 1},
#   'sentiment': {'document': {'score': 0.929622, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 49, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 69, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 85, 'features': 1},
#   'sentiment': {'document': {'score': 0.999697, 'label': 'positive'}},
# ...
#   'sentiment': {'document': {'score': 0.908403, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 549, 'features': 1},
#   'sentiment': {'document': {'score': -0.404736, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 5, 'features': 1},
#   'sentiment': {'document': {'score': -0.924149, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 213, 'features': 1},
#   'sentiment': {'document': {'score': -0.549857, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 213, 'features': 1},
#   'sentiment': {'document': {'score': -0.549857, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 7, 'features': 1},
#   'sentiment': {'document': {'score': 0.963196, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 33, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 393, 'features': 1},
#   'sentiment': {'document': {'score': -0.43179, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 384, 'features': 1},
#   'sentiment': {'document': {'score': -0.504213, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 195, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 38, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 66, 'features': 1},
#   'sentiment': {'document': {'score': -0.708824, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 40, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 85, 'features': 1},
#   'sentiment': {'document': {'score': -0.732749, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 79, 'features': 1},
#   'sentiment': {'document': {'score': -0.800786, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 78, 'features': 1},
#   'sentiment': {'document': {'score': 0.70393, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 15, 'features': 1},
#   'sentiment': {'document': {'score': -0.662374, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 65, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 75, 'features': 1},
#   'sentiment': {'document': {'score': -0.779834, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 140, 'features': 1},
#   'sentiment': {'document': {'score': 0.248376, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 141, 'features': 1},
#   'sentiment': {'document': {'score': -0.730758, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 64, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 70, 'features': 1},
#   'sentiment': {'document': {'score': -0.78223, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 212, 'features': 1},
#   'sentiment': {'document': {'score': -0.600946, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 169, 'features': 1},
#   'sentiment': {'document': {'score': -0.534678, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 18, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 162, 'features': 1},
#   'sentiment': {'document': {'score': -0.448489, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 68, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 213, 'features': 1},
#   'sentiment': {'document': {'score': -0.298853, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 53, 'features': 1},
#   'sentiment': {'document': {'score': 0.455731, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 43, 'features': 1},
#   'sentiment': {'document': {'score': 0.640883, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 66, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 34, 'features': 1},
#   'sentiment': {'document': {'score': -0.580525, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 150, 'features': 1},
#   'sentiment': {'document': {'score': -0.941687, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 97, 'features': 1},
#   'sentiment': {'document': {'score': -0.946431, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 51, 'features': 1},
#   'sentiment': {'document': {'score': 0.971681, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 258, 'features': 1},
#   'sentiment': {'document': {'score': 0.515962, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 33, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 24, 'features': 1},
#   'sentiment': {'document': {'score': -0.640295, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': 0.997901, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 31, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 1, 'features': 1},
#   'sentiment': {'document': {'score': -0.970791, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 37, 'features': 1},
#   'sentiment': {'document': {'score': -0.797813, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 50, 'features': 1},
#   'sentiment': {'document': {'score': -0.646161, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 110, 'features': 1},
#   'sentiment': {'document': {'score': -0.613444, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 55, 'features': 1},
#   'sentiment': {'document': {'score': -0.892774, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 56, 'features': 1},
#   'sentiment': {'document': {'score': 0.780326, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 21, 'features': 1},
#   'sentiment': {'document': {'score': -0.669393, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 144, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 40, 'features': 1},
#   'sentiment': {'document': {'score': -0.775608, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 55, 'features': 1},
#   'sentiment': {'document': {'score': -0.802804, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 152, 'features': 1},
#   'sentiment': {'document': {'score': 0.562079, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': -0.980149, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 75, 'features': 1},
#   'sentiment': {'document': {'score': -0.491907, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 38, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 142, 'features': 1},
#   'sentiment': {'document': {'score': -0.637057, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 47, 'features': 1},
#   'sentiment': {'document': {'score': -0.584191, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 2, 'features': 1},
#   'sentiment': {'document': {'score': 0.411688, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 208, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 188, 'features': 1},
#   'sentiment': {'document': {'score': -0.450848, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 9, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 316, 'features': 1},
#   'sentiment': {'document': {'score': 0.611861, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 259, 'features': 1},
#   'sentiment': {'document': {'score': -0.675149, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 47, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 102, 'features': 1},
#   'sentiment': {'document': {'score': -0.714599, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 147, 'features': 1},
#   'sentiment': {'document': {'score': -0.939972, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 28, 'features': 1},
#   'sentiment': {'document': {'score': 0.44777, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 111, 'features': 1},
#   'sentiment': {'document': {'score': -0.784821, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 18, 'features': 1},
#   'sentiment': {'document': {'score': 0.580038, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 121, 'features': 1},
#   'sentiment': {'document': {'score': -0.787441, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 120, 'features': 1},
#   'sentiment': {'document': {'score': -0.54887, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 57, 'features': 1},
#   'sentiment': {'document': {'score': -0.877815, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 113, 'features': 1},
#   'sentiment': {'document': {'score': -0.477503, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 113, 'features': 1},
#   'sentiment': {'document': {'score': -0.477503, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 179, 'features': 1},
#   'sentiment': {'document': {'score': -0.660646, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 4, 'features': 1},
#   'sentiment': {'document': {'score': 0.567321, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 37, 'features': 1},
#   'sentiment': {'document': {'score': 0.971285, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 13, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 100, 'features': 1},
#   'sentiment': {'document': {'score': -0.926283, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 108, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 54, 'features': 1},
#   'sentiment': {'document': {'score': -0.598518, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 19, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 24, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 3, 'features': 1},
#   'sentiment': {'document': {'score': 0.937495, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 54, 'features': 1},
#   'sentiment': {'document': {'score': -0.598518, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 54, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 111, 'features': 1},
#   'sentiment': {'document': {'score': -0.610568, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 320, 'features': 1},
#   'sentiment': {'document': {'score': 0.630176, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 17, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 45, 'features': 1},
#   'sentiment': {'document': {'score': -0.506795, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 20, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 130, 'features': 1},
#   'sentiment': {'document': {'score': 0.589022, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 31, 'features': 1},
#   'sentiment': {'document': {'score': 0.393901, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 10, 'features': 1},
#   'sentiment': {'document': {'score': 0.997963, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 29, 'features': 1},
#   'sentiment': {'document': {'score': 0.997547, 'label': 'positive'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 135, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 92, 'features': 1},
#   'sentiment': {'document': {'score': -0.624285, 'label': 'negative'}},
#   'language': 'es'},
#  {'usage': {'text_units': 1, 'text_characters': 201, 'features': 1},
#   'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#   'language': 'es'}]

# %%
test_df = df_rows
for index, row in test_df.iterrows():
    test_df.loc[index,"sentimientos"] = sentimentComentario[index]['sentiment']['document']['score']
test_df.head(5)
# Out:
#    numero de post                                       commentarios  \
# 0               1       Circuito 8-10 para cuándo estará programado?
# 1               1                                                👏👏👏
# 2               2  De verdad aún no entiendo… nuevas medidas y si...
# 3               2  Siempre dice; arraijan, vista alegre_ arraijan...
# 4               2  Quisiera saber donde están vacunando la 2a dos...
#
#    sentimientos
# 0      0.000000
# 1      0.524743
# 2     -0.578034
# 3      0.892413
# 4      0.000000

# %%
test_df.to_csv("Comentarios.csv",index=False)

# %%
df2_test = test_df
df_post = df2_test.groupby('numero de post')['sentimientos'].mean()
df_post.to_csv("postsentiment.csv", index=True)

# %%
test_df2 = df2_rows
df2_rows['key'] = keywordDescripcion
df2_rows
# Out:
#     numero de post                fecha  \
# 0                1  27 de julio de 2021
# 1                2  26 de julio de 2021
# 2                3  26 de julio de 2021
# 3                4  26 de julio de 2021
# 4                5  26 de julio de 2021
# 5                6  26 de julio de 2021
# 6                7  26 de julio de 2021
# 7                8  26 de julio de 2021
# 8                9  26 de julio de 2021
# 9               10  26 de julio de 2021
# 10              11  26 de julio de 2021
# 11              12  26 de julio de 2021
# 12              13  26 de julio de 2021
# 13              14  26 de julio de 2021
# 14              15  26 de julio de 2021
# 15              16  26 de julio de 2021
# 16              17  25 de julio de 2021
# 17              18  25 de julio de 2021
# 18              19  25 de julio de 2021
# 19              20  25 de julio de 2021
# 20              21  25 de julio de 2021
# 21              22  25 de julio de 2021
# 22              23  25 de julio de 2021
# 23              24  25 de julio de 2021
# 24              25  25 de julio de 2021
# 25              26  25 de julio de 2021
# 26              27  25 de julio de 2021
# 27              28  24 de julio de 2021
# 28              29  24 de julio de 2021
# 29              30  24 de julio de 2021
# 30              31  24 de julio de 2021
# 31              32  24 de julio de 2021
# 32              33  24 de julio de 2021
# 33              34                 none
# 34              35  23 de julio de 2021
# 35              36  23 de julio de 2021
# 36              37  23 de julio de 2021
# 37              38  22 de julio de 2021
# 38              39  22 de julio de 2021
# 39              40  22 de julio de 2021
# 40              41  21 de julio de 2021
# 41              42  21 de julio de 2021
# 42              43  19 de julio de 2021
# 43              44  19 de julio de 2021
# 44              45  19 de julio de 2021
# 45              46  19 de julio de 2021
# 46              47  18 de julio de 2021
# 47              48  18 de julio de 2021
# 48              49  18 de julio de 2021
# 49              50  18 de julio de 2021
# 50              51  18 de julio de 2021
# 51              52  18 de julio de 2021
# 52              53  17 de julio de 2021
# 53              54  17 de julio de 2021
# 54              55  17 de julio de 2021
# 55              56  17 de julio de 2021
# 56              57  17 de julio de 2021
#
#                                               caption  \
# 0   ¡Llegan 456,300 nuevas dosis Pfizer! Estas dos...
# 1   Desglose de corregimientos con más casos en el...
# 2   Compartimos la actualización de datos sobre #C...
# 3   Comunicado N° 517 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 4   Nuevas medidas que empezarán a regir a partir ...
# 5   #Herrera | Tras los barridos realizados en las...
# 6   #ComarcaNgäbeBuglé | La Región de Salud de la ...
# 7   #LosSantos | Recibimos 5,004 dosis de Pfizer p...
# 8   #Chiriquí | Con un total de 74,130 dosis aplic...
# 9   #Coclé | Con éxito culmina barrido de Pfizer e...
# 10  #Veraguas | ¡Se mantiene el proceso de vacunac...
# 11  #Chiriquí | ¡62,442 dosis de Pfizer llegan a l...
# 12  #Veraguas | Un nuevo lote de 42,498 dosis de P...
# 13  #BocasDelToro | Este lunes continúan las accio...
# 14  #BocasDelToro | Los Equipos de Respuesta Rápid...
# 15  #LosSantos | Habilitamos un puesto de hisopado...
# 16  Distribución de los casos de #COVID19 por prov...
# 17  Compartimos la actualización de datos sobre #C...
# 18  Comunicado N° 516 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 19  #Chiriquí | Este domingo se realizó con éxito ...
# 20  #PanamáMetro | La operación #PanavaC19 sigue d...
# 21  "Hemos firmado con las autoridades costarricen...
# 22  #PanamáMetro | Son cientos de jóvenes desde lo...
# 23  #PanamáMetro | El Equipo #PanavaC19 en conjunt...
# 24  #BuenGobiernoComunica en Salud\n\n⬇️\n✅Llegan ...
# 25  #Herrera | El equipo de Promoción de la Salud ...
# 26  #Chiriquí | Nos mantenemos realizando inspecci...
# 27  #PanamáMetro| Realizamos un operativo nocturno...
# 28  Desglose de corregimientos con más casos en el...
# 29  Compartimos la actualización de datos sobre #C...
# 30  Comunicado N° 515 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 31  ¡101,944 dosis aplicadas el día de hoy! Compro...
# 32  Más de 2 millones de dosis de vacunas contra e...
# 33                                               none
# 34  ¡La Operación #PanavaC19 sigue avanzando en el...
# 35  Un total de 163,000 dosis de la vacuna AstraZe...
# 36  El Ministro @LPacoSucre junto a Stewart Tuttle...
# 37  Agradecemos a la Iglesia de Jesucristo de Los ...
# 38  #Veraguas | Se mantiene en orden el proceso de...
# 39  📍Centros de vacunación habilitados en el circu...
# 40  #Chiriquí | Con gran entusiasmo inicia esta ma...
# 41  #Veraguas | ¡Inicia el proceso de vacunación c...
# 42  Comunicado N° 510 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 43  #LosSantos | Con 25,240 dosis de la casa farma...
# 44  #SanMiguelito | Seguimos avanzando con la oper...
# 45  #PanamáOeste | Como parte de las estrategias s...
# 46  Desglose de corregimientos con más casos en el...
# 47  Compartimos la actualización de datos sobre #C...
# 48  Comunicado N° 509 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 49  #SanMiguelito | La Región de Salud informa que...
# 50  #BuenGobiernoComunica en Salud\n\n✅Llega el lo...
# 51  Este 18 de julio conmemoramos el #DíaDelNiñoYL...
# 52  Desglose de corregimientos con más casos en el...
# 53  Compartimos la actualización de datos sobre #C...
# 54  Comunicado N° 508 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 55  #Herrera | Continúa con gran éxito la vacunaci...
# 56  #LosSantos | ¡La operación #PanavaC19 no se de...
#
#                             palabrasClave  \
# 0                            nuevas dosis
# 1              Desglose de corregimientos
# 2                  actualización de datos
# 3        UnPanamáMejor🇵🇦 #ProtégetePanamá
# 4                          Nuevas medidas
# 5                                #Herrera
# 6           Región de Salud de la Comarca
# 7                         dosis de Pfizer
# 8               dosis aplicadas de Pfizer
# 9                          primeras dosis
# 10                  proceso de vacunación
# 11                        dosis de Pfizer
# 12                             nuevo lote
# 13         acciones del personal de Salud
# 14                        atención médica
# 15                     puesto de hisopado
# 16  Distribución de los casos de #COVID19
# 17                 actualización de datos
# 18       UnPanamáMejor🇵🇦 #ProtégetePanamá
# 19                         día de barrido
# 20                   operación #PanavaC19
# 21             autoridades costarricenses
# 22              años de edad del circuito
# 23                      Equipo #PanavaC19
# 24                             Costa Rica
# 25        equipo de Promoción de la Salud
# 26                    nebulización de día
# 27                          Casco Antiguo
# 28             Desglose de corregimientos
# 29                 actualización de datos
# 30       UnPanamáMejor🇵🇦 #ProtégetePanamá
# 31                  salud de la población
# 32                    equipo comprometido
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN
# 46                                    NaN
# 47                                    NaN
# 48                                    NaN
# 49                                    NaN
# 50                                    NaN
# 51                                    NaN
# 52                                    NaN
# 53                                    NaN
# 54                                    NaN
# 55                                    NaN
# 56                                    NaN
#
#                                                   key
# 0   {'usage': {'text_units': 1, 'text_characters':...
# 1   {'usage': {'text_units': 1, 'text_characters':...
# 2   {'usage': {'text_units': 1, 'text_characters':...
# 3   {'usage': {'text_units': 1, 'text_characters':...
# 4   {'usage': {'text_units': 1, 'text_characters':...
# 5   {'usage': {'text_units': 1, 'text_characters':...
# 6   {'usage': {'text_units': 1, 'text_characters':...
# 7   {'usage': {'text_units': 1, 'text_characters':...
# 8   {'usage': {'text_units': 1, 'text_characters':...
# 9   {'usage': {'text_units': 1, 'text_characters':...
# 10  {'usage': {'text_units': 1, 'text_characters':...
# 11  {'usage': {'text_units': 1, 'text_characters':...
# 12  {'usage': {'text_units': 1, 'text_characters':...
# 13  {'usage': {'text_units': 1, 'text_characters':...
# 14  {'usage': {'text_units': 1, 'text_characters':...
# 15  {'usage': {'text_units': 1, 'text_characters':...
# 16  {'usage': {'text_units': 1, 'text_characters':...
# 17  {'usage': {'text_units': 1, 'text_characters':...
# 18  {'usage': {'text_units': 1, 'text_characters':...
# 19  {'usage': {'text_units': 1, 'text_characters':...
# 20  {'usage': {'text_units': 1, 'text_characters':...
# 21  {'usage': {'text_units': 1, 'text_characters':...
# 22  {'usage': {'text_units': 1, 'text_characters':...
# 23  {'usage': {'text_units': 1, 'text_characters':...
# 24  {'usage': {'text_units': 1, 'text_characters':...
# 25  {'usage': {'text_units': 1, 'text_characters':...
# 26  {'usage': {'text_units': 1, 'text_characters':...
# 27  {'usage': {'text_units': 1, 'text_characters':...
# 28  {'usage': {'text_units': 1, 'text_characters':...
# 29  {'usage': {'text_units': 1, 'text_characters':...
# 30  {'usage': {'text_units': 1, 'text_characters':...
# 31  {'usage': {'text_units': 1, 'text_characters':...
# 32  {'usage': {'text_units': 1, 'text_characters':...
# 33  {'usage': {'text_units': 1, 'text_characters':...
# 34  {'usage': {'text_units': 1, 'text_characters':...
# 35  {'usage': {'text_units': 1, 'text_characters':...
# 36  {'usage': {'text_units': 1, 'text_characters':...
# 37  {'usage': {'text_units': 1, 'text_characters':...
# 38  {'usage': {'text_units': 1, 'text_characters':...
# 39  {'usage': {'text_units': 1, 'text_characters':...
# 40  {'usage': {'text_units': 1, 'text_characters':...
# 41  {'usage': {'text_units': 1, 'text_characters':...
# 42  {'usage': {'text_units': 1, 'text_characters':...
# 43  {'usage': {'text_units': 1, 'text_characters':...
# 44  {'usage': {'text_units': 1, 'text_characters':...
# 45  {'usage': {'text_units': 1, 'text_characters':...
# 46  {'usage': {'text_units': 1, 'text_characters':...
# 47  {'usage': {'text_units': 1, 'text_characters':...
# 48  {'usage': {'text_units': 1, 'text_characters':...
# 49  {'usage': {'text_units': 1, 'text_characters':...
# 50  {'usage': {'text_units': 1, 'text_characters':...
# 51  {'usage': {'text_units': 1, 'text_characters':...
# 52  {'usage': {'text_units': 1, 'text_characters':...
# 53  {'usage': {'text_units': 1, 'text_characters':...
# 54  {'usage': {'text_units': 1, 'text_characters':...
# 55  {'usage': {'text_units': 1, 'text_characters':...
# 56  {'usage': {'text_units': 1, 'text_characters':...

# %%
for index, row in test_df2.iterrows():
    test_df2.loc[index,"palabrasClave"] = df2_rows.iloc[index]['key']['keywords'][0]['text']
    
test_df2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-ed3970736858> in <module>
#       1 for index, row in test_df2.iterrows():
# ----> 2     test_df2.loc[index,"palabrasClave"] = df2_rows.iloc[index]['key']['keywords'][0]['text']
#       3
#       4 test_df2
#
# IndexError: list index out of range

# %%
test_df2
# Out:
#     numero de post                fecha  \
# 0                1  27 de julio de 2021
# 1                2  26 de julio de 2021
# 2                3  26 de julio de 2021
# 3                4  26 de julio de 2021
# 4                5  26 de julio de 2021
# 5                6  26 de julio de 2021
# 6                7  26 de julio de 2021
# 7                8  26 de julio de 2021
# 8                9  26 de julio de 2021
# 9               10  26 de julio de 2021
# 10              11  26 de julio de 2021
# 11              12  26 de julio de 2021
# 12              13  26 de julio de 2021
# 13              14  26 de julio de 2021
# 14              15  26 de julio de 2021
# 15              16  26 de julio de 2021
# 16              17  25 de julio de 2021
# 17              18  25 de julio de 2021
# 18              19  25 de julio de 2021
# 19              20  25 de julio de 2021
# 20              21  25 de julio de 2021
# 21              22  25 de julio de 2021
# 22              23  25 de julio de 2021
# 23              24  25 de julio de 2021
# 24              25  25 de julio de 2021
# 25              26  25 de julio de 2021
# 26              27  25 de julio de 2021
# 27              28  24 de julio de 2021
# 28              29  24 de julio de 2021
# 29              30  24 de julio de 2021
# 30              31  24 de julio de 2021
# 31              32  24 de julio de 2021
# 32              33  24 de julio de 2021
# 33              34                 none
# 34              35  23 de julio de 2021
# 35              36  23 de julio de 2021
# 36              37  23 de julio de 2021
# 37              38  22 de julio de 2021
# 38              39  22 de julio de 2021
# 39              40  22 de julio de 2021
# 40              41  21 de julio de 2021
# 41              42  21 de julio de 2021
# 42              43  19 de julio de 2021
# 43              44  19 de julio de 2021
# 44              45  19 de julio de 2021
# 45              46  19 de julio de 2021
# 46              47  18 de julio de 2021
# 47              48  18 de julio de 2021
# 48              49  18 de julio de 2021
# 49              50  18 de julio de 2021
# 50              51  18 de julio de 2021
# 51              52  18 de julio de 2021
# 52              53  17 de julio de 2021
# 53              54  17 de julio de 2021
# 54              55  17 de julio de 2021
# 55              56  17 de julio de 2021
# 56              57  17 de julio de 2021
#
#                                               caption  \
# 0   ¡Llegan 456,300 nuevas dosis Pfizer! Estas dos...
# 1   Desglose de corregimientos con más casos en el...
# 2   Compartimos la actualización de datos sobre #C...
# 3   Comunicado N° 517 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 4   Nuevas medidas que empezarán a regir a partir ...
# 5   #Herrera | Tras los barridos realizados en las...
# 6   #ComarcaNgäbeBuglé | La Región de Salud de la ...
# 7   #LosSantos | Recibimos 5,004 dosis de Pfizer p...
# 8   #Chiriquí | Con un total de 74,130 dosis aplic...
# 9   #Coclé | Con éxito culmina barrido de Pfizer e...
# 10  #Veraguas | ¡Se mantiene el proceso de vacunac...
# 11  #Chiriquí | ¡62,442 dosis de Pfizer llegan a l...
# 12  #Veraguas | Un nuevo lote de 42,498 dosis de P...
# 13  #BocasDelToro | Este lunes continúan las accio...
# 14  #BocasDelToro | Los Equipos de Respuesta Rápid...
# 15  #LosSantos | Habilitamos un puesto de hisopado...
# 16  Distribución de los casos de #COVID19 por prov...
# 17  Compartimos la actualización de datos sobre #C...
# 18  Comunicado N° 516 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 19  #Chiriquí | Este domingo se realizó con éxito ...
# 20  #PanamáMetro | La operación #PanavaC19 sigue d...
# 21  "Hemos firmado con las autoridades costarricen...
# 22  #PanamáMetro | Son cientos de jóvenes desde lo...
# 23  #PanamáMetro | El Equipo #PanavaC19 en conjunt...
# 24  #BuenGobiernoComunica en Salud\n\n⬇️\n✅Llegan ...
# 25  #Herrera | El equipo de Promoción de la Salud ...
# 26  #Chiriquí | Nos mantenemos realizando inspecci...
# 27  #PanamáMetro| Realizamos un operativo nocturno...
# 28  Desglose de corregimientos con más casos en el...
# 29  Compartimos la actualización de datos sobre #C...
# 30  Comunicado N° 515 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 31  ¡101,944 dosis aplicadas el día de hoy! Compro...
# 32  Más de 2 millones de dosis de vacunas contra e...
# 33                                               none
# 34  ¡La Operación #PanavaC19 sigue avanzando en el...
# 35  Un total de 163,000 dosis de la vacuna AstraZe...
# 36  El Ministro @LPacoSucre junto a Stewart Tuttle...
# 37  Agradecemos a la Iglesia de Jesucristo de Los ...
# 38  #Veraguas | Se mantiene en orden el proceso de...
# 39  📍Centros de vacunación habilitados en el circu...
# 40  #Chiriquí | Con gran entusiasmo inicia esta ma...
# 41  #Veraguas | ¡Inicia el proceso de vacunación c...
# 42  Comunicado N° 510 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 43  #LosSantos | Con 25,240 dosis de la casa farma...
# 44  #SanMiguelito | Seguimos avanzando con la oper...
# 45  #PanamáOeste | Como parte de las estrategias s...
# 46  Desglose de corregimientos con más casos en el...
# 47  Compartimos la actualización de datos sobre #C...
# 48  Comunicado N° 509 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 49  #SanMiguelito | La Región de Salud informa que...
# 50  #BuenGobiernoComunica en Salud\n\n✅Llega el lo...
# 51  Este 18 de julio conmemoramos el #DíaDelNiñoYL...
# 52  Desglose de corregimientos con más casos en el...
# 53  Compartimos la actualización de datos sobre #C...
# 54  Comunicado N° 508 #UnPanamáMejor🇵🇦 #ProtégeteP...
# 55  #Herrera | Continúa con gran éxito la vacunaci...
# 56  #LosSantos | ¡La operación #PanavaC19 no se de...
#
#                             palabrasClave  \
# 0                            nuevas dosis
# 1              Desglose de corregimientos
# 2                  actualización de datos
# 3        UnPanamáMejor🇵🇦 #ProtégetePanamá
# 4                          Nuevas medidas
# 5                                #Herrera
# 6           Región de Salud de la Comarca
# 7                         dosis de Pfizer
# 8               dosis aplicadas de Pfizer
# 9                          primeras dosis
# 10                  proceso de vacunación
# 11                        dosis de Pfizer
# 12                             nuevo lote
# 13         acciones del personal de Salud
# 14                        atención médica
# 15                     puesto de hisopado
# 16  Distribución de los casos de #COVID19
# 17                 actualización de datos
# 18       UnPanamáMejor🇵🇦 #ProtégetePanamá
# 19                         día de barrido
# 20                   operación #PanavaC19
# 21             autoridades costarricenses
# 22              años de edad del circuito
# 23                      Equipo #PanavaC19
# 24                             Costa Rica
# 25        equipo de Promoción de la Salud
# 26                    nebulización de día
# 27                          Casco Antiguo
# 28             Desglose de corregimientos
# 29                 actualización de datos
# 30       UnPanamáMejor🇵🇦 #ProtégetePanamá
# 31                  salud de la población
# 32                    equipo comprometido
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN
# 46                                    NaN
# 47                                    NaN
# 48                                    NaN
# 49                                    NaN
# 50                                    NaN
# 51                                    NaN
# 52                                    NaN
# 53                                    NaN
# 54                                    NaN
# 55                                    NaN
# 56                                    NaN
#
#                                                   key
# 0   {'usage': {'text_units': 1, 'text_characters':...
# 1   {'usage': {'text_units': 1, 'text_characters':...
# 2   {'usage': {'text_units': 1, 'text_characters':...
# 3   {'usage': {'text_units': 1, 'text_characters':...
# 4   {'usage': {'text_units': 1, 'text_characters':...
# 5   {'usage': {'text_units': 1, 'text_characters':...
# 6   {'usage': {'text_units': 1, 'text_characters':...
# 7   {'usage': {'text_units': 1, 'text_characters':...
# 8   {'usage': {'text_units': 1, 'text_characters':...
# 9   {'usage': {'text_units': 1, 'text_characters':...
# 10  {'usage': {'text_units': 1, 'text_characters':...
# 11  {'usage': {'text_units': 1, 'text_characters':...
# 12  {'usage': {'text_units': 1, 'text_characters':...
# 13  {'usage': {'text_units': 1, 'text_characters':...
# 14  {'usage': {'text_units': 1, 'text_characters':...
# 15  {'usage': {'text_units': 1, 'text_characters':...
# 16  {'usage': {'text_units': 1, 'text_characters':...
# 17  {'usage': {'text_units': 1, 'text_characters':...
# 18  {'usage': {'text_units': 1, 'text_characters':...
# 19  {'usage': {'text_units': 1, 'text_characters':...
# 20  {'usage': {'text_units': 1, 'text_characters':...
# 21  {'usage': {'text_units': 1, 'text_characters':...
# 22  {'usage': {'text_units': 1, 'text_characters':...
# 23  {'usage': {'text_units': 1, 'text_characters':...
# 24  {'usage': {'text_units': 1, 'text_characters':...
# 25  {'usage': {'text_units': 1, 'text_characters':...
# 26  {'usage': {'text_units': 1, 'text_characters':...
# 27  {'usage': {'text_units': 1, 'text_characters':...
# 28  {'usage': {'text_units': 1, 'text_characters':...
# 29  {'usage': {'text_units': 1, 'text_characters':...
# 30  {'usage': {'text_units': 1, 'text_characters':...
# 31  {'usage': {'text_units': 1, 'text_characters':...
# 32  {'usage': {'text_units': 1, 'text_characters':...
# 33  {'usage': {'text_units': 1, 'text_characters':...
# 34  {'usage': {'text_units': 1, 'text_characters':...
# 35  {'usage': {'text_units': 1, 'text_characters':...
# 36  {'usage': {'text_units': 1, 'text_characters':...
# 37  {'usage': {'text_units': 1, 'text_characters':...
# 38  {'usage': {'text_units': 1, 'text_characters':...
# 39  {'usage': {'text_units': 1, 'text_characters':...
# 40  {'usage': {'text_units': 1, 'text_characters':...
# 41  {'usage': {'text_units': 1, 'text_characters':...
# 42  {'usage': {'text_units': 1, 'text_characters':...
# 43  {'usage': {'text_units': 1, 'text_characters':...
# 44  {'usage': {'text_units': 1, 'text_characters':...
# 45  {'usage': {'text_units': 1, 'text_characters':...
# 46  {'usage': {'text_units': 1, 'text_characters':...
# 47  {'usage': {'text_units': 1, 'text_characters':...
# 48  {'usage': {'text_units': 1, 'text_characters':...
# 49  {'usage': {'text_units': 1, 'text_characters':...
# 50  {'usage': {'text_units': 1, 'text_characters':...
# 51  {'usage': {'text_units': 1, 'text_characters':...
# 52  {'usage': {'text_units': 1, 'text_characters':...
# 53  {'usage': {'text_units': 1, 'text_characters':...
# 54  {'usage': {'text_units': 1, 'text_characters':...
# 55  {'usage': {'text_units': 1, 'text_characters':...
# 56  {'usage': {'text_units': 1, 'text_characters':...

# %%
test_df2.to_csv("Post",index=False)

# %% [markdown]
# Add the `responses` list and the `normalize` to the df_rows dataframe. We can continue to use these new data features, but more commonly we'll derive new dataframes for our experiments and change those new dataframes instead.

# %% [markdown]
# Let's create a new dataframe where we can pull out the column for the `emotion` `anger`, then sort by the highest rating of `anger`.
